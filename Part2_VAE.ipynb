# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bm}[1]{{\bf #1}}
# \newcommand{\bb}[1]{\bm{\mathrm{#1}}}
# $$
#
# # Part 2: Variational Autoencoder
# <a id=part2></a>

# %% [markdown]
# In this part we will learn to generate new data using a special type of autoencoder model which allows us to
# sample from it's latent space. We'll implement and train a VAE and use it to generate new images.

# %%
import unittest
import os
import sys
import pathlib
import urllib
import shutil
import re
import zipfile

import numpy as np
import torch
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

test = unittest.TestCase()
plt.rcParams.update({'font.size': 12})
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cpu

# %% [markdown]
# ### Obtaining the dataset
# <a id=part2_1></a>

# %% [markdown]
# Let's begin by downloading a dataset of images that we want to learn to generate.
# We'll use the [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) (LFW) dataset which contains many labels faces of famous individuals.
#
# We're going to train our generative model to generate a specific face, not just any face.
# Since the person with the most images in this dataset is former president George W. Bush, we'll set out to train a Bush Generator :)
#
# However, if you feel adventurous and/or prefer to generate something else, feel free to edit the `PART2_CUSTOM_DATA_URL` variable in `hw3/answers.py`.

# %%
import cs236605.plot as plot
import cs236605.download
from hw3.answers import PART2_CUSTOM_DATA_URL as CUSTOM_DATA_URL

DATA_DIR = pathlib.Path.home().joinpath('.pytorch-datasets')
if CUSTOM_DATA_URL is None:
    DATA_URL = 'http://vis-www.cs.umass.edu/lfw/lfw-bush.zip'
else:
    DATA_URL = CUSTOM_DATA_URL

_, dataset_dir = cs236605.download.download_data(out_path=DATA_DIR, url=DATA_URL, extract=True, force=False)
# Out:
# File /Users/natouda/.pytorch-datasets/lfw-bush.zip exists, skipping download.
# Extracting /Users/natouda/.pytorch-datasets/lfw-bush.zip...
# Extracted 531 to /Users/natouda/.pytorch-datasets/lfw/George_W_Bush

# %% [markdown]
# Create a `Dataset` object that will load the extraced images:

# %%
import torchvision.transforms as T
from torchvision.datasets import ImageFolder

im_size = 64
tf = T.Compose([
    # Resize to constant spatial dimensions
    T.Resize((im_size, im_size)),
    # PIL.Image -> torch.Tensor
    T.ToTensor(),
    # Dynamic range [0,1] -> [-1, 1]
    T.Normalize(mean=(.5,.5,.5), std=(.5,.5,.5)),
])

ds_gwb = ImageFolder(os.path.dirname(dataset_dir), tf)

# %% [markdown]
# OK, let's see what we got. You can run the following block multiple times to display a random subset of images from the dataset.

# %%
_ = plot.dataset_first_n(ds_gwb, 50, figsize=(10,5), nrows=5)
print(f'Found {len(ds_gwb)} images in dataset folder.')
# Out:
# Found 530 images in dataset folder.

# %%
x0, y0 = ds_gwb[0]
x0 = x0.unsqueeze(0).to(device)
print(x0.shape)

test.assertSequenceEqual(x0.shape, (1, 3, im_size, im_size))
# Out:
# torch.Size([1, 3, 64, 64])

# %% [markdown]
# ## The Variational Autoencoder
# <a id=part2_2></a>

# %% [markdown]
# An autoencoder is a model which learns a representation of data in an **unsupervised** fashion (i.e without any labels).
# Recall it's general form from the lecture:
#
# <img src="imgs/autoencoder.jpg"/>

# %% [markdown]
# An autoencoder maps an instance $\bb{x}$ to a **latent-space** representation $\bb{z}$.
# It has an encoder part, $\Phi_{\bb{\alpha}}(\bb{x})$ (a neural net with parameters $\bb{\alpha}$)
# and a decoder part, $\Psi_{\bb{\beta}}(\bb{z})$ (a neural net with parameters $\bb{\beta}$).
#
# While autoencoders can learn useful representations,
# generally it's hard to use them as generative models because there's no distribution we can sample from in the latent space. In other words, we have no way to choose a point $\bb{z}$ in the latent space
# such that $\Psi(\bb{z})$ will end up on the data manifold in the instance space.
#
# <img src="imgs/ae_sampling.jpg"/>

# %% [markdown]
# The variational autoencoder (VAE), first proposed by [Kingma and Welling](https://arxiv.org/pdf/1312.6114.pdf), addresses this issue by taking a probabilistic perspective.
# Briefly, a VAE model can be described as follows.
#
# We define, in Baysean terminology,
# - The **prior** distribution $p(\bb{Z})$ on points in the latent space.
# - The **likelihood** distribution of a sample $\bb{X}$ given a latent-space representation: $p(\bb{X}|\bb{Z})$.
# - The **posterior** distribution of points in the latent spaces given a specific instance: $p(\bb{Z}|\bb{X})$.
# - The **evidence** distribution $p(\bb{X})$ which is the distribution of the instance space due to the generative process.

# %% [markdown]
# To create our variational **decoder** we'll further specify:
#
# - A parametric likelihood distribution, $p _{\bb{\beta}}(\bb{X} | \bb{z}) = \mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$. The interpretation is that given a latent $\bb{z}$, we map it to a point normally distributed around the point calculated by our decoder neural network. Note that here $\sigma^2$ is a hyperparameter while $\vec{\beta}$ represents the network parameters.
# - A fixed latent-space prior distribution of $p(\bb{Z}) = \mathcal{N}(\bb{0},\bb{I})$.
#
# This setting allows us to generate a new instance $\bb{x}$ by sampling $\bb{z}$ from the multivariate normal
# distribution, obtaining the instance-space mean $\Psi _{\bb{\beta}}(\bb{z})$ using our decoder network,
# and then sampling $\bb{x}$ from $\mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$.

# %% [markdown]
# Our variational **encoder** will approximate the posterior with a parametric distribution
# $q _{\bb{\alpha}}(\bb{Z} | \bb{x}) \sim
# \mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$.
# The interpretation is that our encoder neural network, $\Phi_{\vec{\alpha}}(\bb{x})$, calculates
# the mean and variance of the posterior distribution, and samples $\bb{z}$ based on them.
# An important nuance here is that our network can't contain any stochastic elements that
# depend on the model parameters, otherwise we won't be able to back-propagate to those parameters.
# So sampling $\bb{z}$ from $\mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$ is not an option.
# The solution is to use what's known as the **reparametrization trick**: sample from an isotropic Gaussian,
# i.e. $\bb{u}\sim\mathcal{N}(\bb{0},\bb{I})$ (which doesn't depend on trainable parameters), and calculate the latent representation as
# $\bb{z} = \bb{\mu} _{\bb{\alpha}}(\bb{x}) + \bb{u}\odot\bb{\sigma}^2_{\bb{\alpha}}(\bb{x})$.

# %% [markdown]
# To train a VAE model, we would like to maximize the evidence, $p(\bb{X})$, because
# $
# p(\bb{X}) = \int p(\bb{X}|{\bb{z}})p(\bb{z})d\bb{z}
# $
# thus maximizing the likelihood of generated instances from over the entire latent space.
#
# The **VAE loss** can therefore be stated as minimizing $\mathcal{L} = -\mathbb{E}_{\bb{x}} \log p(\bb{X})$.
# As we saw in the lecture, this expectation is intractable,
# but we can obtain a lower-bound for $p(\bb{X})$ (the evidence lower bound, "ELBO"):
#
# $$
# \log p(\bb{X}) \ge \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }( \log  p _{\bb{\beta}}(\bb{X} | \bb{z}) )
# -  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{X})\,\left\|\, p(\bb{Z} )\right.\right)
# $$
#
# where
# $
# \mathcal{D} _{\mathrm{KL}}(q\left\|\right.p) =
# \mathbb{E}_{\bb{z}\sim q}\left[ \log \frac{q(\bb{Z})}{p(\bb{Z})} \right]
# $
# is the Kullback-Liebler divergence, which can be interpreted as the information gained by using the posterior $q(\bb{Z|X})$ instead of the prior distribution $p(\bb{Z})$.
#
# Using the ELBO, the VAE loss becomes,
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }\left[ -\log  p _{\bb{\beta}}(\bb{x} | \bb{z}) \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$
#
# By remembering that the likelihood is a Gaussian distribution with a diagonal covariance and by applying the reparametrization trick, we can write the above as
#
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }
# \left[
# \frac{1}{2\sigma^2}\left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  + \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2
# \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$

# %% [markdown]
# ### Model Implementation
# <a id=part2_3></a>

# %% [markdown]
# Obviously our model will have two parts, an encoder and a decoder.
# Since we're working with images, we'll implement both as deep **convolutional** networks, where the decoder is a "mirror image" of the encoder implemented with adjoint (AKA transposed) convolutions.
# Between the encoder CNN and the decoder CNN we'll implement the sampling from
# the parametric posterior approximator $q_{\bb{\alpha}}(\bb{Z}|\bb{x})$
# to make it a VAE model and not just a regular autoencoder (of course, this is not yet enough to create a VAE,
# since we also need a special loss function which we'll get to later).

# %% [markdown]
# First let's implement just the CNN part of the Encoder network
# (this is not the full $\Phi_{\vec{\alpha}}(\bb{x})$ yet).
# As usual, it should take an input image and map to an activation volume of a specified depth.
# We'll consider this volume as the features we extract from the input image.
# Later we'll use these to create the latent space representation of the input.
# which will be our latent space representation.

# %% [markdown]
# **TODO**: Implement the `EncoderCNN` class in the `hw3/autoencoder.py` module.
# Implement any CNN architecture you like. If you need "architecture inspiration" you can see e.g. [this](https://arxiv.org/pdf/1512.09300.pdf) or [this](https://arxiv.org/pdf/1511.06434.pdf) paper.

# %%
import hw3.autoencoder as autoencoder

in_channels = 3
out_channels = 1024
encoder_cnn = autoencoder.EncoderCNN(in_channels, out_channels).to(device)
print(encoder_cnn)

h = encoder_cnn(x0)
print(x0.shape)
print(h.shape)

test.assertEqual(h.dim(), 4)
test.assertSequenceEqual(h.shape[0:2], (1, out_channels))
# Out:
# EncoderCNN(
#   (cnn): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU()
#     (6): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (8): ReLU()
#     (9): Conv2d(128, 1024, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   )
# )
# torch.Size([1, 3, 64, 64])
# torch.Size([1, 1024, 1, 1])

# %% [markdown]
# Now let's implement the CNN part of the Decoder.
# Again this is not yet the full $\Psi _{\bb{\beta}}(\bb{z})$. It should take an activation volume produced
# by your `EncoderCNN` and output an image of the same dimensions as the Encoder's input was.
# This should be a CNN which is a "mirror image" of the the Encoder. For example, replace convolutions with transposed convolutions, downsampling with up-sampling etc.
# Consult the documentation of [ConvTranspose2D](https://pytorch.org/docs/0.4.1/nn.html#convtranspose2d)
# to figure out how to reverse your convolutional layers in terms of input and output dimensions.

# %% [markdown]
# **TODO**: Implement the `DecoderCNN` class in the `hw3/autoencoder.py` module.

# %%
decoder_cnn = autoencoder.DecoderCNN(in_channels=out_channels, out_channels=in_channels).to(device)
print(decoder_cnn)
x0r = decoder_cnn(h)
print(x0r.shape)

test.assertEqual(x0.shape, x0r.shape)

# Should look like colored noise
T.functional.to_pil_image(x0r[0].cpu().detach())
# Out:
# DecoderCNN(
#   (cnn): Sequential(
#     (0): ConvTranspose2d(1024, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (1): Upsample(scale_factor=4, mode=bilinear)
#     (2): ReLU()
#     (3): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): Upsample(scale_factor=4, mode=bilinear)
#     (5): ReLU()
#     (6): ConvTranspose2d(64, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): Upsample(scale_factor=4, mode=bilinear)
#     (8): ReLU()
#     (9): Conv2d(32, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   )
# )
# torch.Size([1, 3, 64, 64])
# /Users/natouda/miniconda3/envs/cs236605-hw/lib/python3.7/site-packages/torch/nn/modules/upsampling.py:122: UserWarning: nn.Upsampling is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.Upsampling is deprecated. Use nn.functional.interpolate instead.")
# <PIL.Image.Image image mode=RGB size=64x64 at 0x11C728BA8>

# %% [markdown]
# Let's now implement the full VAE Encoder, $\Phi_{\vec{\alpha}}(\vec{x})$.
# It will work as follows:
# 1. Produce a feature vector $\vec{h}$ from the input image $\vec{x}$.
# 2. Use two affine transforms to convert the features into the mean and log-variance of the posterior, i.e.
#     $$
#     \begin{align}
#         \bb{\mu} _{\bb{\alpha}}(\bb{x}) &= \vec{h}\mattr{W}_{\mathrm{h\mu}} + \vec{b}_{\mathrm{h\mu}} \\
#         \log\left(\bb{\sigma}^2_{\bb{\alpha}}(\bb{x})\right) &= \vec{h}\mattr{W}_{\mathrm{h\sigma^2}} + \vec{b}_{\mathrm{h\sigma^2}}
#     \end{align}
#     $$
# 3. Use the **reparametrization trick** to create the latent representation $\vec{z}$.
#
# Note that we model the **log** of the variance, not the actual variance.
# The reason is that the log is easier to optimize, since (a) It doesn't have to be positive, and (b) it has a much larger dynamic range.
# The above formulation is proposed in appendix C of the [VAE paper](https://arxiv.org/pdf/1312.6114.pdf).

# %% [markdown]
# **TODO**: Implement the `encode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`.

# %%
z_dim = 2
vae = autoencoder.VAE(encoder_cnn, decoder_cnn, x0[0].size(), z_dim).to(device)
# print(vae)

z, mu, log_sigma2 = vae.encode(x0)

print('z shape - ', z.shape)
test.assertSequenceEqual(z.shape, (1, z_dim))
test.assertTrue(z.shape == mu.shape == log_sigma2.shape)

print(f'mu(x0)={list(*mu.detach().cpu().numpy())}, sigma2(x0)={list(*torch.exp(log_sigma2).detach().cpu().numpy())}')

# Sample from q(Z|x)
N = 500
Z = torch.zeros(N, z_dim)
_, ax = plt.subplots()
with torch.no_grad():
    for i in range(500):
        Z[i], _, _ = vae.encode(x0)
        ax.scatter(*Z[i].cpu().numpy())

# Should be close to the above
print('sampled mu', torch.mean(Z, dim=0))
print('sampled sigma2', torch.var(Z, dim=0))
# Out:
# z shape -  torch.Size([1, 2])
# mu(x0)=[-0.58575934, -0.9300158], sigma2(x0)=[1.1542122, 0.51433855]
# sampled mu tensor([-0.6126, -0.9747])
# sampled sigma2 tensor([1.0316, 0.4939])

# %% [markdown]
# Let's now implement the full VAE Decoder, $\Psi _{\bb{\beta}}(\bb{z})$.
# It will work as follows:
# 1. Produce a feature vector $\tilde{\vec{h}}$ from the latent vector $\vec{z}$ using an affine transform.
# 2. Reconstruct an image $\tilde{\vec{x}}$ from $\tilde{\vec{h}}$.

# %% [markdown]
# **TODO**: Implement the `decode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`. You may need to also re-run the block above after you implement this.

# %%
x0r = vae.decode(z)

test.assertSequenceEqual(x0r.shape, x0.shape)

# %% [markdown]
# Our model's `forward()` function will simply return `decode(encode(x))` as well as the calculated mean and log-variance of the posterior.

# %%
x0r, mu, log_sigma2 = vae(x0)

test.assertSequenceEqual(x0r.shape, x0.shape)
test.assertSequenceEqual(mu.shape, (1, z_dim))
test.assertSequenceEqual(log_sigma2.shape, (1, z_dim))
T.functional.to_pil_image(x0r[0].detach().cpu())
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x12240E630>

# %% [markdown]
# ### Loss Implementation
# <a id=part2_4></a>

# %% [markdown]
# In practice, since we're using SGD, we'll drop the expectation over $\bb{X}$ and instead sample an instance from the training set and compute a point-wise loss. Similarly, we'll drop the expectation over $\bb{Z}$ by sampling from $q_{\vec{\alpha}}(\bb{Z}|\bb{x})$.
# Additionally, because the KL divergence is between two Gaussian distributions, there is a closed-form expression for it. These points bring us to the following point-wise loss:
#
# $$
# \ell(\vec{\alpha},\vec{\beta};\bb{x}) =
# \frac{1}{\sigma^2} \left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  +
# \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2 +
# \mathrm{tr}\,\bb{\Sigma} _{\bb{\alpha}}(\bb{x}) +  \|\bb{\mu} _{\bb{\alpha}}(\bb{x})\|^2 _2 - d_z - \log\det \bb{\Sigma} _{\bb{\alpha}}(\bb{x})
# $$
#
# where $d_z$ is the dimension of the latent space. This pointwise loss is the quantity that we'll compute and minimize with gradient descent.

# %% [markdown]
# **TODO**: Implement the `vae_loss()` function in the `hw3/autoencoder.py` module.

# %%
from hw3.autoencoder import vae_loss
torch.manual_seed(42)

def test_vae_loss():
    # Test data
    N, C, H, W = 10, 3, 64, 64 
    z_dim = 32
    x  = torch.randn(N, C, H, W)*2 - 1
    xr = torch.randn(N, C, H, W)*2 - 1
    z_mu = torch.randn(N, z_dim)
    z_log_sigma2 = torch.randn(N, z_dim)
    x_sigma2 = 0.9
    
    loss, _, _ = vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)
    
    test.assertAlmostEqual(loss.item(), 10.5053434, delta=1e-5)
    return loss

test_vae_loss()
# Out:
# tensor(10.5053)

# %% [markdown]
# ### Sampling
# <a id=part2_5></a>

# %% [markdown]
# The main advantage of a VAE is that it can by used as a generative model by sampling the latent space, since
# we optimize for a Normal prior $p(\bb{Z})$ in the loss function. Let's now implement this so that we can visualize how our model is doing when we train.

# %% [markdown]
# **TODO**: Implement the `sample()` method in the `VAE` class within the `hw3/autoencoder.py` module.

# %%
samples = vae.sample(5)
_ = plot.tensors_as_images(samples)

# %% [markdown]
# ### Training
# <a id=part2_6></a>

# %% [markdown]
# Time to train!

# %% [markdown]
# **TODO**:
# 1. Implement the `VAETrainer` class in the `hw3/training.py` module.
# 2. Tweak the hyperparameters in the `part2_vae_hyperparam()` function within the `hw3/answers.py` module.

# %%
import torch.optim as optim
from torch.utils.data import random_split
from torch.utils.data import DataLoader
from torch.nn import DataParallel
from hw3.training import VAETrainer
from hw3.answers import part2_vae_hyperparams

torch.manual_seed(42)

# Hyperparams
hp = part2_vae_hyperparams()
batch_size = hp['batch_size']
h_dim = hp['h_dim']
z_dim = hp['z_dim']
x_sigma2 = hp['x_sigma2']
learn_rate = hp['learn_rate']
betas = hp['betas']

# Data
split_lengths = [int(len(ds_gwb)*0.9), int(len(ds_gwb)*0.1)]
ds_train, ds_test = random_split(ds_gwb, split_lengths)
dl_train = DataLoader(ds_train, batch_size, shuffle=True)
dl_test  = DataLoader(ds_test,  batch_size, shuffle=True)
im_size = ds_train[0][0].shape

# Model
print(im_size)
encoder = autoencoder.EncoderCNN(in_channels=im_size[0], out_channels=h_dim)
decoder = autoencoder.DecoderCNN(in_channels=h_dim, out_channels=im_size[0])
vae = autoencoder.VAE(encoder, decoder, im_size, z_dim)
vae_dp = DataParallel(vae).to(device)

# Optimizer
optimizer = optim.Adam(vae.parameters(), lr=learn_rate, betas=betas)

# Loss
def loss_fn(x, xr, z_mu, z_log_sigma2):
    return autoencoder.vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)

# Trainer
trainer = VAETrainer(vae_dp, loss_fn, optimizer, device)
checkpoint_file = 'checkpoints/vae'
checkpoint_file_final = f'{checkpoint_file}_final'
if os.path.isfile(f'{checkpoint_file}.pt'):
    os.remove(f'{checkpoint_file}.pt')

# Show model and hypers
print(vae)
print(hp)
# Out:
# torch.Size([3, 64, 64])
# VAE(
#   (features_encoder): EncoderCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#       (3): ReLU()
#       (4): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#       (7): ReLU()
#       (8): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#       (11): ReLU()
#       (12): Conv2d(128, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (cnn): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): Upsample(scale_factor=4, mode=bilinear)
#       (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): ReLU()
#       (4): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (5): Upsample(scale_factor=4, mode=bilinear)
#       (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): ConvTranspose2d(64, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (9): Upsample(scale_factor=4, mode=bilinear)
#       (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Conv2d(32, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#   )
# )
# {'batch_size': 32, 'h_dim': 256, 'z_dim': 5, 'x_sigma2': 0.9, 'learn_rate': 0.001, 'betas': (0.1, 0.1)}

# %%
import IPython.display

def post_epoch_fn(epoch, train_result, test_result, verbose):
    # Plot some samples if this is a verbose epoch
    if verbose:
        samples = vae.sample(n=5)
        fig, _ = plot.tensors_as_images(samples, figsize=(6,2))
        IPython.display.display(fig)
        plt.close(fig)

if os.path.isfile(f'{checkpoint_file_final}.pt'):
    print(f'*** Loading final checkpoint file {checkpoint_file_final} instead of training')
    checkpoint_file = checkpoint_file_final
else:
    res = trainer.fit(dl_train, dl_test,
                      num_epochs=200, early_stopping=20, print_every=10,
                      checkpoints=checkpoint_file,
                      post_epoch_fn=post_epoch_fn)
    
# Plot images from best model
saved_state = torch.load(f'{checkpoint_file}.pt', map_location=device)
vae_dp.load_state_dict(saved_state['model_state'])
print('*** Images Generated from best model:')
fig, _ = plot.tensors_as_images(vae_dp.module.sample(n=15), nrows=3, figsize=(6,6))

# %%
from hw3.experiments import load_experiment
from cs236605.plot import plot_fit
from IPython.display import Image


def plotResults(description,RunName):
    Res = 'results/'
    exp = Res + RunName + '/MEGA_RUN' + description + '.json'
    
    imagefile = Res + RunName + '/MEGA_RUN' + description + '_Ep_39.png'
    
    
    cfg, fit_res = load_experiment(exp)
    _, _ = plot_fit(fit_res)
    
    
#     Image(imagefile)
    return imagefile

# %%
RES1 = './results/Res5/'

D = np.load(RES1 + 'RunFinal.npy').item()
i = 0
for key in D.keys():
    print(key , ' - ' ,D[key])
    i+= 1
    if i % 4 == 0:
        print()
# Out:
# h_128z_5lr_0.01  -  {'train': 0.30652058124542236, 'test': 0.2986984923481941}
# h_128z_5lr_0.0005  -  {'train': 0.2779108186562856, 'test': 0.3020031601190567}
# h_128z_10lr_0.01  -  {'train': 0.6461444000403086, 'test': 0.7272700667381287}
# h_128z_10lr_0.0005  -  {'train': 0.2565289502342542, 'test': 0.2977176383137703}
#
# h_128z_20lr_0.01  -  Failed... ################ loss is Inf/Nan... ################
# h_128z_20lr_0.0005  -  {'train': 0.26097466399272284, 'test': 0.2811531722545624}
# h_128z_50lr_0.01  -  {'train': 0.3557478278875351, 'test': 0.301606435328722}
# h_128z_50lr_0.0005  -  {'train': 0.2598225424687068, 'test': 0.2916687950491905}
#
# h_256z_5lr_0.01  -  {'train': 0.640538074572881, 'test': 0.7148826271295547}
# h_256z_5lr_0.0005  -  {'train': 0.2625452866156896, 'test': 0.282739520072937}
# h_256z_10lr_0.01  -  {'train': 0.6512717803319296, 'test': 0.7353864312171936}
# h_256z_10lr_0.0005  -  {'train': 0.25545040567715965, 'test': 0.24822849035263062}
#
# h_256z_20lr_0.01  -  {'train': 0.6377719144026438, 'test': 0.7230611741542816}
# h_256z_20lr_0.0005  -  {'train': 0.26432869881391524, 'test': 0.31325584650039673}
# h_256z_50lr_0.01  -  {'train': 0.6559924602508544, 'test': 0.7314817756414413}
# h_256z_50lr_0.0005  -  {'train': 0.251174550751845, 'test': 0.2439556084573269}
#
# h_512z_5lr_0.01  -  {'train': 0.6292480538288753, 'test': 0.7090646326541901}
# h_512z_5lr_0.0005  -  {'train': 0.27742757499217985, 'test': 0.29051053524017334}
# h_512z_10lr_0.01  -  {'train': 0.6555239975452423, 'test': 0.7397968918085098}
# h_512z_10lr_0.0005  -  {'train': 0.2707180480162303, 'test': 0.25643473491072655}
#
# h_512z_20lr_0.01  -  Failed... cannot identify image file <_io.BufferedReader name='/home/natsala/.pytorch-datasets/lfw/George_W_Bush/George_W_Bush_0310.jpg'>
# h_512z_20lr_0.0005  -  {'train': 0.2658921380837758, 'test': 0.2470346763730049}
# h_512z_50lr_0.01  -  {'train': 0.34471724132696785, 'test': 0.3155270144343376}
# h_512z_50lr_0.0005  -  {'train': 0.2641102413336436, 'test': 0.24241409823298454}

# %%
from hw3.experiments import load_experiment
from cs236605.plot import plot_fit
from IPython.display import Image

# There should now be a file 'test_run.json' in your `results/` folder.
# We can use it to load the results of the experiment.
# cfg, fit_res = load_experiment('results/Res1/MEGA_RUNlr_0.0005s_0.9.json')
# _, _ = plot_fit(fit_res)

# # image_file = './results/MEGA_RUNlr_0.0005s_0.9_Ep_99.png'
# imagefile = 'results/MEGA_RUNlr_0.0005s_0.9_Ep_99.png'
# Image(imagefile)

# filename = plotResults('bs_16lr_0.001s_0.9', 'Res2')

# Image(filename)


filename = plotResults('lr_0.001s_0.95', 'Res4')
print(filename)
Image(filename)
# Out:
# results/Res4/MEGA_RUNlr_0.001s_0.95_Ep_99.png

# %%
# lr - 0.001 , s - 0.8
f = 'results/Res4/MEGA_RUNlr_0.001s_0.8_Ep_99.png'
Image(f)

# %%
# lr - 0.0005 , s - 0.95
f = 'results/Res4/MEGA_RUNlr_0.0005s_0.95_Ep_99.png'
Image(f)

# %%
RES1 = './results/Res5/'

D = np.load(RES1 + 'RunFinal.npy').item()
i = 0
for key in D.keys():
    print(key , ' - ' ,D[key])
    i+= 1
    if i % 4 == 0:
        print()
# Out:
# h_128z_5lr_0.01  -  {'train': 0.30652058124542236, 'test': 0.2986984923481941}
# h_128z_5lr_0.0005  -  {'train': 0.2779108186562856, 'test': 0.3020031601190567}
# h_128z_10lr_0.01  -  {'train': 0.6461444000403086, 'test': 0.7272700667381287}
# h_128z_10lr_0.0005  -  {'train': 0.2565289502342542, 'test': 0.2977176383137703}
#
# h_128z_20lr_0.01  -  Failed... ################ loss is Inf/Nan... ################
# h_128z_20lr_0.0005  -  {'train': 0.26097466399272284, 'test': 0.2811531722545624}
# h_128z_50lr_0.01  -  {'train': 0.3557478278875351, 'test': 0.301606435328722}
# h_128z_50lr_0.0005  -  {'train': 0.2598225424687068, 'test': 0.2916687950491905}
#
# h_256z_5lr_0.01  -  {'train': 0.640538074572881, 'test': 0.7148826271295547}
# h_256z_5lr_0.0005  -  {'train': 0.2625452866156896, 'test': 0.282739520072937}
# h_256z_10lr_0.01  -  {'train': 0.6512717803319296, 'test': 0.7353864312171936}
# h_256z_10lr_0.0005  -  {'train': 0.25545040567715965, 'test': 0.24822849035263062}
#
# h_256z_20lr_0.01  -  {'train': 0.6377719144026438, 'test': 0.7230611741542816}
# h_256z_20lr_0.0005  -  {'train': 0.26432869881391524, 'test': 0.31325584650039673}
# h_256z_50lr_0.01  -  {'train': 0.6559924602508544, 'test': 0.7314817756414413}
# h_256z_50lr_0.0005  -  {'train': 0.251174550751845, 'test': 0.2439556084573269}
#
# h_512z_5lr_0.01  -  {'train': 0.6292480538288753, 'test': 0.7090646326541901}
# h_512z_5lr_0.0005  -  {'train': 0.27742757499217985, 'test': 0.29051053524017334}
# h_512z_10lr_0.01  -  {'train': 0.6555239975452423, 'test': 0.7397968918085098}
# h_512z_10lr_0.0005  -  {'train': 0.2707180480162303, 'test': 0.25643473491072655}
#
# h_512z_20lr_0.01  -  Failed... cannot identify image file <_io.BufferedReader name='/home/natsala/.pytorch-datasets/lfw/George_W_Bush/George_W_Bush_0310.jpg'>
# h_512z_20lr_0.0005  -  {'train': 0.2658921380837758, 'test': 0.2470346763730049}
# h_512z_50lr_0.01  -  {'train': 0.34471724132696785, 'test': 0.3155270144343376}
# h_512z_50lr_0.0005  -  {'train': 0.2641102413336436, 'test': 0.24241409823298454}

# %%
filename = plotResults('h_256z_50lr_0.0005', 'Res7')
print(filename)
Image(filename)
# Out:
# results/Res7/MEGA_RUNh_256z_50lr_0.0005_Ep_39.png

# %%
# Lets try an experiment

from hw3.answers import part2_vae_hyperparams
from hw3.experiments import run_experiment
from hw3.autoencoder import AutoEncoderError 
import numpy as np
     
Init_Name = 'MEGA_RUN'
OUTDIR = './results/Res4/'

AllResults = {}

bs = 16
h_dim = 256
z_dim = 128
Epochs = 100
lr = 0.0005
s = 0.9


try:           
    name = 'lr_' + str(lr) + 's_' + str(s)
    res = run_experiment(Init_Name + name, out_dir=OUTDIR, seed=42,
                        # Training params
                        bs_train=8, bs_test=None, batches=100, epochs=Epochs,
                        early_stopping=10, checkpoints=None, lr=lr,
                        RTplot=True, print_every=5,
                        # Model params
                        h_dim=h_dim, z_dim=z_dim, x_sigma2=s)
    AllResults[name] = res
except AutoEncoderError as e:
    AllResults[name] = 'Failed... ' + str(e)
except OSError as e:
    AllResults[name] = 'Failed... ' + str(e)
    
            
np.save(OUTDIR + 'RunFinal', AllResults)
# Out:
# File /Users/natouda/.pytorch-datasets/lfw-bush.zip exists, skipping download.
# Extracting /Users/natouda/.pytorch-datasets/lfw-bush.zip...
# Extracted 531 to /Users/natouda/.pytorch-datasets/lfw/George_W_Bush
# train_batch (Avg. Loss 1.592, Accuracy 52.2): 100%|██████████| 60/60 [00:27<00:00,  2.21it/s]
# test_batch (Avg. Loss 1.685, Accuracy 19.3): 100%|██████████| 7/7 [00:01<00:00,  6.02it/s]
# train_batch (Avg. Loss 0.919, Accuracy 58.1): 100%|██████████| 60/60 [00:28<00:00,  2.51it/s]
# test_batch (Avg. Loss 1.188, Accuracy 19.3): 100%|██████████| 7/7 [00:00<00:00,  7.42it/s]
# train_batch (Avg. Loss 0.606, Accuracy 60.9): 100%|██████████| 60/60 [00:27<00:00,  2.41it/s]
# test_batch (Avg. Loss 1.006, Accuracy 19.7): 100%|██████████| 7/7 [00:01<00:00,  7.43it/s]
# train_batch (Avg. Loss 0.465, Accuracy 62.8): 100%|██████████| 60/60 [00:26<00:00,  2.37it/s]
# test_batch (Avg. Loss 0.961, Accuracy 19.1): 100%|██████████| 7/7 [00:01<00:00,  6.85it/s]
# train_batch (Avg. Loss 0.391, Accuracy 64.0): 100%|██████████| 60/60 [00:29<00:00,  2.07it/s]
# test_batch (Avg. Loss 0.880, Accuracy 18.7): 100%|██████████| 7/7 [00:01<00:00,  6.89it/s]
# --- EPOCH 6/100 ---
# train_batch (Avg. Loss 0.344, Accuracy 65.1): 100%|██████████| 60/60 [00:26<00:00,  2.55it/s]
# test_batch (Avg. Loss 0.733, Accuracy 22.9): 100%|██████████| 7/7 [00:01<00:00,  6.96it/s]
# train_batch (Avg. Loss 0.310, Accuracy 67.3): 100%|██████████| 60/60 [00:26<00:00,  2.25it/s]
# test_batch (Avg. Loss 0.705, Accuracy 22.3): 100%|██████████| 7/7 [00:01<00:00,  5.93it/s]
# train_batch (Avg. Loss 0.291, Accuracy 66.7): 100%|██████████| 60/60 [00:27<00:00,  2.44it/s]
# test_batch (Avg. Loss 0.771, Accuracy 20.1): 100%|██████████| 7/7 [00:01<00:00,  6.95it/s]
# train_batch (Avg. Loss 0.270, Accuracy 68.5): 100%|██████████| 60/60 [00:29<00:00,  2.36it/s]
# test_batch (Avg. Loss 0.723, Accuracy 21.0): 100%|██████████| 7/7 [00:01<00:00,  6.96it/s]
# train_batch (Avg. Loss 0.255, Accuracy 70.2): 100%|██████████| 60/60 [00:30<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.712, Accuracy 21.2): 100%|██████████| 7/7 [00:01<00:00,  6.72it/s]
# --- EPOCH 11/100 ---
# train_batch (Avg. Loss 0.249, Accuracy 70.2): 100%|██████████| 60/60 [00:30<00:00,  1.96it/s]
# test_batch (Avg. Loss 0.810, Accuracy 18.1): 100%|██████████| 7/7 [00:01<00:00,  4.93it/s]
# train_batch (Avg. Loss 0.239, Accuracy 71.6): 100%|██████████| 60/60 [00:33<00:00,  2.08it/s]
# test_batch (Avg. Loss 0.746, Accuracy 20.3): 100%|██████████| 7/7 [00:01<00:00,  6.37it/s]
# train_batch (Avg. Loss 0.236, Accuracy 71.5): 100%|██████████| 60/60 [00:29<00:00,  2.52it/s]
# test_batch (Avg. Loss 0.683, Accuracy 21.5): 100%|██████████| 7/7 [00:00<00:00,  7.27it/s]
# train_batch (Avg. Loss 0.236, Accuracy 70.3): 100%|██████████| 60/60 [00:31<00:00,  2.12it/s]
# test_batch (Avg. Loss 0.723, Accuracy 21.4): 100%|██████████| 7/7 [00:01<00:00,  5.29it/s]
# train_batch (Avg. Loss 0.231, Accuracy 71.9): 100%|██████████| 60/60 [00:30<00:00,  2.52it/s]
# test_batch (Avg. Loss 0.764, Accuracy 19.2): 100%|██████████| 7/7 [00:00<00:00,  7.69it/s]
# --- EPOCH 16/100 ---
# train_batch (Avg. Loss 0.225, Accuracy 72.9): 100%|██████████| 60/60 [00:25<00:00,  2.59it/s]
# test_batch (Avg. Loss 0.729, Accuracy 20.5): 100%|██████████| 7/7 [00:00<00:00,  7.69it/s]
# train_batch (Avg. Loss 0.219, Accuracy 75.0): 100%|██████████| 60/60 [00:26<00:00,  2.52it/s]
# test_batch (Avg. Loss 0.914, Accuracy 15.7): 100%|██████████| 7/7 [00:00<00:00,  7.01it/s]
# train_batch (Avg. Loss 0.214, Accuracy 76.7): 100%|██████████| 60/60 [00:27<00:00,  2.56it/s]
# test_batch (Avg. Loss 0.758, Accuracy 19.1): 100%|██████████| 7/7 [00:00<00:00,  7.47it/s]
# train_batch (Avg. Loss 0.213, Accuracy 76.9): 100%|██████████| 60/60 [00:25<00:00,  2.59it/s]
# test_batch (Avg. Loss 0.850, Accuracy 16.8): 100%|██████████| 7/7 [00:00<00:00,  7.72it/s]
# train_batch (Avg. Loss 0.212, Accuracy 76.8): 100%|██████████| 60/60 [00:26<00:00,  2.62it/s]
# test_batch (Avg. Loss 0.764, Accuracy 18.5): 100%|██████████| 7/7 [00:00<00:00,  7.37it/s]
# --- EPOCH 21/100 ---
# train_batch (Avg. Loss 0.210, Accuracy 78.1): 100%|██████████| 60/60 [00:27<00:00,  2.43it/s]
# test_batch (Avg. Loss 0.718, Accuracy 19.9): 100%|██████████| 7/7 [00:01<00:00,  7.21it/s]
# train_batch (Avg. Loss 0.207, Accuracy 78.5): 100%|██████████| 60/60 [00:26<00:00,  2.52it/s]
# test_batch (Avg. Loss 0.750, Accuracy 18.8): 100%|██████████| 7/7 [00:01<00:00,  7.38it/s]
# train_batch (Avg. Loss 0.206, Accuracy 79.2): 100%|██████████| 60/60 [00:27<00:00,  2.32it/s]
# test_batch (Avg. Loss 0.814, Accuracy 17.8): 100%|██████████| 7/7 [00:00<00:00,  7.39it/s]
# train_batch (Avg. Loss 0.205, Accuracy 78.3): 100%|██████████| 60/60 [00:26<00:00,  2.58it/s]
# test_batch (Avg. Loss 0.795, Accuracy 17.7): 100%|██████████| 7/7 [00:00<00:00,  7.25it/s]
# train_batch (Avg. Loss 0.207, Accuracy 77.8): 100%|██████████| 60/60 [00:25<00:00,  2.57it/s]
# test_batch (Avg. Loss 0.801, Accuracy 17.6): 100%|██████████| 7/7 [00:00<00:00,  7.74it/s]
# --- EPOCH 26/100 ---
# train_batch (Avg. Loss 0.203, Accuracy 79.4): 100%|██████████| 60/60 [00:25<00:00,  2.56it/s]
# test_batch (Avg. Loss 0.736, Accuracy 19.5): 100%|██████████| 7/7 [00:00<00:00,  7.57it/s]
# train_batch (Avg. Loss 0.199, Accuracy 81.1): 100%|██████████| 60/60 [00:25<00:00,  2.52it/s]
# test_batch (Avg. Loss 0.837, Accuracy 16.8): 100%|██████████| 7/7 [00:00<00:00,  7.66it/s]
# train_batch (Avg. Loss 0.200, Accuracy 80.1): 100%|██████████| 60/60 [00:25<00:00,  2.59it/s]
# test_batch (Avg. Loss 0.763, Accuracy 18.5): 100%|██████████| 7/7 [00:00<00:00,  7.34it/s]
# train_batch (Avg. Loss 0.200, Accuracy 80.3): 100%|██████████| 60/60 [00:26<00:00,  2.40it/s]
# test_batch (Avg. Loss 0.808, Accuracy 17.6): 100%|██████████| 7/7 [00:00<00:00,  7.09it/s]
# train_batch (Avg. Loss 0.201, Accuracy 80.3): 100%|██████████| 60/60 [00:32<00:00,  2.32it/s]
# test_batch (Avg. Loss 0.766, Accuracy 18.8): 100%|██████████| 7/7 [00:01<00:00,  6.85it/s]
# --- EPOCH 31/100 ---
# train_batch (Avg. Loss 0.195, Accuracy 81.6): 100%|██████████| 60/60 [00:29<00:00,  2.33it/s]
# test_batch (Avg. Loss 0.768, Accuracy 18.5): 100%|██████████| 7/7 [00:01<00:00,  7.08it/s]
# train_batch (Avg. Loss 0.194, Accuracy 82.4): 100%|██████████| 60/60 [00:27<00:00,  2.53it/s]
# test_batch (Avg. Loss 0.846, Accuracy 17.3): 100%|██████████| 7/7 [00:00<00:00,  7.37it/s]
# train_batch (Avg. Loss 0.192, Accuracy 83.4): 100%|██████████| 60/60 [00:29<00:00,  2.20it/s]
# test_batch (Avg. Loss 0.725, Accuracy 19.6): 100%|██████████| 7/7 [00:01<00:00,  6.11it/s]
# train_batch (Avg. Loss 0.191, Accuracy 83.8): 100%|██████████| 60/60 [00:26<00:00,  2.52it/s]
# test_batch (Avg. Loss 0.832, Accuracy 16.8): 100%|██████████| 7/7 [00:00<00:00,  7.60it/s]
# train_batch (Avg. Loss 0.194, Accuracy 82.5): 100%|██████████| 60/60 [00:27<00:00,  2.22it/s]
# test_batch (Avg. Loss 0.762, Accuracy 18.4): 100%|██████████| 7/7 [00:01<00:00,  6.87it/s]
# --- EPOCH 36/100 ---
# train_batch (Avg. Loss 0.186, Accuracy 86.0): 100%|██████████| 60/60 [00:26<00:00,  2.55it/s]
# test_batch (Avg. Loss 0.728, Accuracy 19.7): 100%|██████████| 7/7 [00:00<00:00,  7.74it/s]
# train_batch (Avg. Loss 0.189, Accuracy 84.1): 100%|██████████| 60/60 [00:30<00:00,  2.39it/s]
# test_batch (Avg. Loss 0.763, Accuracy 18.4): 100%|██████████| 7/7 [00:01<00:00,  5.16it/s]
# train_batch (Avg. Loss 0.184, Accuracy 86.8): 100%|██████████| 60/60 [00:26<00:00,  2.55it/s]
# test_batch (Avg. Loss 0.701, Accuracy 19.9): 100%|██████████| 7/7 [00:00<00:00,  7.32it/s]
# train_batch (Avg. Loss 0.184, Accuracy 86.0): 100%|██████████| 60/60 [00:26<00:00,  2.52it/s]
# test_batch (Avg. Loss 0.836, Accuracy 16.6): 100%|██████████| 7/7 [00:00<00:00,  7.15it/s]
# train_batch (Avg. Loss 0.182, Accuracy 87.5): 100%|██████████| 60/60 [00:25<00:00,  2.52it/s]
# test_batch (Avg. Loss 0.792, Accuracy 18.5): 100%|██████████| 7/7 [00:00<00:00,  7.35it/s]
# --- EPOCH 41/100 ---
# train_batch (Avg. Loss 0.184, Accuracy 86.8): 100%|██████████| 60/60 [00:27<00:00,  2.51it/s]
# test_batch (Avg. Loss 0.829, Accuracy 17.0): 100%|██████████| 7/7 [00:00<00:00,  7.50it/s]
# train_batch (Avg. Loss 0.182, Accuracy 87.4): 100%|██████████| 60/60 [00:26<00:00,  2.38it/s]
# test_batch (Avg. Loss 0.706, Accuracy 19.9): 100%|██████████| 7/7 [00:00<00:00,  7.46it/s]
# train_batch (Avg. Loss 0.180, Accuracy 88.0): 100%|██████████| 60/60 [00:26<00:00,  2.51it/s]
# test_batch (Avg. Loss 0.747, Accuracy 19.0): 100%|██████████| 7/7 [00:00<00:00,  7.49it/s]
# train_batch (Avg. Loss 0.177, Accuracy 89.4): 100%|██████████| 60/60 [00:26<00:00,  2.58it/s]
# test_batch (Avg. Loss 0.730, Accuracy 19.2): 100%|██████████| 7/7 [00:00<00:00,  7.46it/s]
# train_batch (Avg. Loss 0.176, Accuracy 90.3): 100%|██████████| 60/60 [00:28<00:00,  2.21it/s]
# test_batch (Avg. Loss 0.789, Accuracy 17.7): 100%|██████████| 7/7 [00:01<00:00,  6.87it/s]
# --- EPOCH 46/100 ---
# train_batch (Avg. Loss 0.176, Accuracy 90.9): 100%|██████████| 60/60 [00:28<00:00,  2.41it/s]
# test_batch (Avg. Loss 0.671, Accuracy 21.0): 100%|██████████| 7/7 [00:01<00:00,  6.22it/s]
# train_batch (Avg. Loss 0.174, Accuracy 91.5): 100%|██████████| 60/60 [00:27<00:00,  2.43it/s]
# test_batch (Avg. Loss 0.725, Accuracy 19.5): 100%|██████████| 7/7 [00:00<00:00,  7.08it/s]
# train_batch (Avg. Loss 0.173, Accuracy 90.9): 100%|██████████| 60/60 [00:29<00:00,  2.02it/s]
# test_batch (Avg. Loss 0.751, Accuracy 18.8): 100%|██████████| 7/7 [00:01<00:00,  5.80it/s]
# train_batch (Avg. Loss 0.173, Accuracy 92.0): 100%|██████████| 60/60 [00:26<00:00,  2.59it/s]
# test_batch (Avg. Loss 0.774, Accuracy 17.9): 100%|██████████| 7/7 [00:00<00:00,  7.78it/s]
# train_batch (Avg. Loss 0.174, Accuracy 91.0): 100%|██████████| 60/60 [00:27<00:00,  2.52it/s]
# test_batch (Avg. Loss 0.790, Accuracy 17.8): 100%|██████████| 7/7 [00:01<00:00,  7.28it/s]
# --- EPOCH 51/100 ---
# train_batch (Avg. Loss 0.170, Accuracy 92.9): 100%|██████████| 60/60 [00:29<00:00,  2.50it/s]
# test_batch (Avg. Loss 0.719, Accuracy 19.4): 100%|██████████| 7/7 [00:00<00:00,  7.17it/s]
# train_batch (Avg. Loss 0.166, Accuracy 95.5): 100%|██████████| 60/60 [00:28<00:00,  2.34it/s]
# test_batch (Avg. Loss 0.706, Accuracy 20.4): 100%|██████████| 7/7 [00:01<00:00,  6.54it/s]
# train_batch (Avg. Loss 0.170, Accuracy 92.4): 100%|██████████| 60/60 [00:28<00:00,  2.25it/s]
# test_batch (Avg. Loss 0.710, Accuracy 19.7): 100%|██████████| 7/7 [00:01<00:00,  6.68it/s]
# train_batch (Avg. Loss 0.169, Accuracy 93.3): 100%|██████████| 60/60 [00:28<00:00,  2.51it/s]
# test_batch (Avg. Loss 0.730, Accuracy 19.3): 100%|██████████| 7/7 [00:00<00:00,  7.24it/s]
# train_batch (Avg. Loss 0.168, Accuracy 94.1): 100%|██████████| 60/60 [00:27<00:00,  2.49it/s]
# test_batch (Avg. Loss 0.767, Accuracy 18.3): 100%|██████████| 7/7 [00:00<00:00,  7.50it/s]
# --- EPOCH 56/100 ---
# train_batch (Avg. Loss 0.168, Accuracy 93.3): 100%|██████████| 60/60 [00:27<00:00,  2.29it/s]
# test_batch (Avg. Loss 0.772, Accuracy 18.4): 100%|██████████| 7/7 [00:01<00:00,  7.29it/s]
# train_batch (Avg. Loss 0.169, Accuracy 93.3): 100%|██████████| 60/60 [00:29<00:00,  2.14it/s]
# test_batch (Avg. Loss 0.831, Accuracy 16.8): 100%|██████████| 7/7 [00:00<00:00,  7.16it/s]
# train_batch (Avg. Loss 0.167, Accuracy 94.0): 100%|██████████| 60/60 [00:26<00:00,  2.54it/s]
# test_batch (Avg. Loss 0.773, Accuracy 17.9): 100%|██████████| 7/7 [00:00<00:00,  7.83it/s]
# train_batch (Avg. Loss 0.166, Accuracy 94.6): 100%|██████████| 60/60 [00:26<00:00,  2.47it/s]
# test_batch (Avg. Loss 0.712, Accuracy 19.5): 100%|██████████| 7/7 [00:00<00:00,  7.88it/s]
# train_batch (Avg. Loss 0.164, Accuracy 95.5): 100%|██████████| 60/60 [00:28<00:00,  2.50it/s]
# test_batch (Avg. Loss 0.692, Accuracy 20.2): 100%|██████████| 7/7 [00:01<00:00,  6.77it/s]
# --- EPOCH 61/100 ---
# train_batch (Avg. Loss 0.163, Accuracy 96.6): 100%|██████████| 60/60 [00:27<00:00,  2.54it/s]
# test_batch (Avg. Loss 0.781, Accuracy 17.9): 100%|██████████| 7/7 [00:00<00:00,  7.57it/s]
# train_batch (Avg. Loss 0.163, Accuracy 96.1): 100%|██████████| 60/60 [00:26<00:00,  2.55it/s]
# test_batch (Avg. Loss 0.775, Accuracy 18.4): 100%|██████████| 7/7 [00:00<00:00,  7.30it/s]
# train_batch (Avg. Loss 0.163, Accuracy 95.5): 100%|██████████| 60/60 [00:29<00:00,  2.12it/s]
# test_batch (Avg. Loss 0.826, Accuracy 16.9): 100%|██████████| 7/7 [00:01<00:00,  6.82it/s]
# train_batch (Avg. Loss 0.163, Accuracy 95.2): 100%|██████████| 60/60 [00:29<00:00,  2.17it/s]
# test_batch (Avg. Loss 0.757, Accuracy 18.3): 100%|██████████| 7/7 [00:01<00:00,  6.76it/s]
# train_batch (0.144):  23%|██▎       | 14/60 [00:07<00:23,  1.95it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-142-ba3b28c704ff> in <module>
#      27                         RTplot=True, print_every=5,
#      28                         # Model params
# ---> 29                         h_dim=h_dim, z_dim=z_dim, x_sigma2=s)
#      30     AllResults[name] = res
#      31 except AutoEncoderError as e:
#
# ~/Desktop/xcodeTechnion/Deep Learning/cs236605-hw3/hw3/experiments.py in run_experiment(run_name, out_dir, seed, bs_train, bs_test, batches, epochs, early_stopping, checkpoints, lr, RTplot, print_every, h_dim, z_dim, x_sigma2, betas, **kw)
#     142     save_experiment(run_name, out_dir, cfg, fit_res)
#     143
# --> 144
#     145     return {'train': last_train_loss, 'test': last_test_loss}
#     146
#
# ~/Desktop/xcodeTechnion/Deep Learning/cs236605-hw3/hw3/training.py in fit(self, dl_train, dl_test, num_epochs, checkpoints, early_stopping, print_every, post_epoch_fn, **kw)
#      88             #   simple regularization technique that is highly recommended.
#      89             # ====== YOUR CODE: ======
# ---> 90             train_result = self.train_epoch(dl_train, **kw)
#      91             test_result = self.test_epoch(dl_test, **kw)
#      92
#
# ~/Desktop/xcodeTechnion/Deep Learning/cs236605-hw3/hw3/training.py in train_epoch(self, dl_train, **kw)
#     141         """
#     142         self.model.train(True)  # set train mode
# --> 143         return self._foreach_batch(dl_train, self.train_batch, **kw)
#     144
#     145     def test_epoch(self, dl_test: DataLoader, **kw) -> EpochResult:
#
# ~/Desktop/xcodeTechnion/Deep Learning/cs236605-hw3/hw3/training.py in _foreach_batch(dl, forward_fn, verbose, max_batches)
#     213             for batch_idx in range(num_batches):
#     214                 data = next(dl_iter)
# --> 215                 batch_res = forward_fn(data)
#     216
#     217                 pbar.set_description(f'{pbar_name} ({batch_res.loss:.3f})')
#
# ~/Desktop/xcodeTechnion/Deep Learning/cs236605-hw3/hw3/training.py in train_batch(self, batch)
#     295
#     296         #forward
# --> 297         xr, z_mu, z_log_sigma2 = self.model(x)
#     298
#     299         #calculate loss
#
# ~/miniconda3/envs/cs236605-hw/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/cs236605-hw/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     116     def forward(self, *inputs, **kwargs):
#     117         if not self.device_ids:
# --> 118             return self.module(*inputs, **kwargs)
#     119         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
#     120         if len(self.device_ids) == 1:
#
# ~/miniconda3/envs/cs236605-hw/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/Desktop/xcodeTechnion/Deep Learning/cs236605-hw3/hw3/autoencoder.py in forward(self, x)
#     208
#     209 def vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2):
# --> 210     """
#     211     Pointwise loss function of a VAE with latent space of dimension z_dim.
#     212     :param x: Input image batch of shape (N,C,H,W).
#
# ~/Desktop/xcodeTechnion/Deep Learning/cs236605-hw3/hw3/autoencoder.py in encode(self, x)
#     151         device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#     152         o = torch.zeros(1,self.z_dim)
# --> 153         u = torch.normal(o,1).to(device)
#     154
#     155
#
# ~/miniconda3/envs/cs236605-hw/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/Desktop/xcodeTechnion/Deep Learning/cs236605-hw3/hw3/autoencoder.py in forward(self, x)
#      36
#      37     def forward(self, x):
# ---> 38         return self.cnn(x)
#      39
#      40
#
# ~/miniconda3/envs/cs236605-hw/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/cs236605-hw/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/miniconda3/envs/cs236605-hw/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/cs236605-hw/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# KeyboardInterrupt:

# %% [markdown]
# ## Questions
# <a id=part2_7></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw3/answers.py`.

# %%
from cs236605.answers import display_answer
import hw3.answers

# %% [markdown]
# ### Question 1
#
# What does the $\sigma^2$ hyperparameter (`x_sigma2` in the code) do? Explain the effect of low and high values.

# %%
display_answer(hw3.answers.part2_q1)
